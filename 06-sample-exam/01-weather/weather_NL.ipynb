# %% [markdown]
# # Data analyse: Het weer
# In het bestand `weather_dataset.csv`vind je weergegevens van verschillende steden. Jouw taak is om deze data op te schonen en te analyseren. Gebruik de voorziene code-velden onder de opdrachten om je code in te schrijven.

# %% [markdown]
# Importeer de packages die je nodig hebt.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Importeer de weergegevens in een DataFrame met de naam `df_weather`.
# * Inspecteer het DataFrame door de eerste 10 rijen te tonen (gebruik hiervoor geen slicing).

# %%
#Import and inspect
df_weather = pd.read_csv("weather_dataset.csv")
df_weather.iloc[0:10]
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
# 5  20000106      1                  3            0.85          1.0244
# 6  20000107      1                  8            0.84          1.0267
# 7  20000108      1                  4            0.79          1.0248
# 8  20000109      1                  8            0.88          1.0243
# 9  20000110      1                  8            0.91          1.0337
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
# 5                    0.56                 0.00             5.7
# 6                    0.20                 0.00             0.0
# 7                    0.54                 0.00             4.3
# 8                    0.11                 0.65             0.0
# 9                    0.06                 0.09             0.0
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# 1              3.6             2.7  ...                 0.5
# 2              2.2             0.1  ...                -1.0
# 3              3.9             0.5  ...                 2.5
# 4              6.0             3.8  ...                -1.8
# 5              4.2             1.9  ...                -0.6
# 6              4.7             1.8  ...                 1.7
# 7              5.6             4.1  ...                 3.5
# 8              4.6             3.8  ...                 3.3
# 9              2.4             1.4  ...                 0.0
#
#    STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                 0.7               1.6            0.97          1.0275
# 1                 2.0               2.0            0.99          1.0293
# 2                 2.8               3.4            0.91          1.0267
# 3                 4.6               4.9            0.95          1.0222
# 4                 2.9               3.6            0.95          1.0209
# 5                 4.0               3.4            0.92          1.0209
# 6                 4.1               2.8            0.96          1.0258
# 7                 6.4               3.6            0.97          1.0210
# 8                 5.1               3.0            0.91          1.0280
# 9                 5.5               1.9            0.94          1.0369
#
#    TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                    0.25                 0.04              8.5
# 1                    0.17                 0.16              7.9
# 2                    0.27                 0.00              8.1
# 3                    0.11                 0.44              8.6
# 4                    0.39                 0.04              8.0
# 5                    0.55                 0.20              7.1
# 6                    0.27                 0.00              6.0
# 7                    0.18                 0.14              8.2
# 8                    0.43                 0.02              5.6
# 9                    0.58                 0.04              1.8
#
#    TOURS_temp_min  TOURS_temp_max
# 0             7.2             9.8
# 1             6.6             9.2
# 2             6.6             9.6
# 3             6.4            10.8
# 4             6.4             9.5
# 5             3.5            10.7
# 6             3.3             8.8
# 7             5.3            11.0
# 8             3.7             7.6
# 9            -1.5             5.0
#
# [10 rows x 165 columns]

# %% [markdown]
# * Verander de data ('datums'/meervoud van datum) in de DATE kolom in pandas datetime objects.
# * Enkel de rijen met data uit 2009 moeten in het dataframe worden opgenomen.

# %%
#datetime objects, year 2009
df_weather["DATE"] = pd.to_datetime(df_weather["DATE"], format= "%Y%m%d")
df_weather = df_weather[df_weather["DATE"].dt.year == 2009]
print(df_weather)
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3288 2009-01-01      1                  4            0.84          1.0284
# 3289 2009-01-02      1                  8            0.89          1.0262
# 3290 2009-01-03      1                  5            0.72          1.0263
# 3291 2009-01-04      1                  4            0.75          1.0239
# 3292 2009-01-05      1                  8            0.84          1.0197
# ...         ...    ...                ...             ...             ...
# 3648 2009-12-27     12                  7            0.80          1.0118
# 3649 2009-12-28     12                  7            0.82          1.0084
# 3650 2009-12-29     12                  7            0.92          1.0028
# 3651 2009-12-30     12                  8            0.92          0.9979
# 3652 2009-12-31     12                  7            0.93          0.9958
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3288                    0.63                 0.00             7.1
# 3289                    0.07                 0.00             0.0
# 3290                    0.50                 0.00             2.9
# 3291                    0.62                 0.00             5.4
# 3292                    0.28                 0.05             0.0
# ...                      ...                  ...             ...
# 3648                    0.37                 0.18             2.3
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 3288              1.5             0.2  ...                -6.0
# 3289             -1.0            -1.8  ...                -8.1
# 3290             -3.1            -6.2  ...                -5.8
# 3291             -3.7            -6.5  ...               -10.8
# 3292             -4.1            -6.4  ...               -12.6
# ...               ...             ...  ...                 ...
# 3648              1.0            -3.9  ...                -7.7
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 3288                -1.9               4.9            0.92          1.0259
# 3289                -4.6               4.9            0.93          1.0245
# 3290                -2.7               6.0            0.79          1.0236
# 3291                -5.8               1.9            0.86          1.0231
# 3292                -8.3               2.0            0.92          1.0181
# ...                  ...               ...             ...             ...
# 3648                -2.7               4.6            0.84          1.0091
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 3288                    0.22                 0.00              0.6
# 3289                    0.08                 0.00             -0.4
# 3290                    0.69                 0.00             -0.1
# 3291                    0.68                 0.00             -2.4
# 3292                    0.18                 0.16             -4.4
# ...                      ...                  ...              ...
# 3648                    0.58                 0.08              4.6
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
#
#       TOURS_temp_min  TOURS_temp_max
# 3288            -0.5             1.7
# 3289            -1.1             0.4
# 3290            -1.4             1.1
# 3291            -5.3             0.5
# 3292            -6.9            -1.9
# ...              ...             ...
# 3648            -0.5             9.7
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
#
# [365 rows x 165 columns]

# %% [markdown]
# * Verwijder de rijen met NaN-waarden

# %%
#NaN
df_weather.dropna(inplace= True)
df_weather
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3288 2009-01-01      1                  4            0.84          1.0284
# 3289 2009-01-02      1                  8            0.89          1.0262
# 3290 2009-01-03      1                  5            0.72          1.0263
# 3291 2009-01-04      1                  4            0.75          1.0239
# 3292 2009-01-05      1                  8            0.84          1.0197
# ...         ...    ...                ...             ...             ...
# 3648 2009-12-27     12                  7            0.80          1.0118
# 3649 2009-12-28     12                  7            0.82          1.0084
# 3650 2009-12-29     12                  7            0.92          1.0028
# 3651 2009-12-30     12                  8            0.92          0.9979
# 3652 2009-12-31     12                  7            0.93          0.9958
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3288                    0.63                 0.00             7.1
# 3289                    0.07                 0.00             0.0
# 3290                    0.50                 0.00             2.9
# 3291                    0.62                 0.00             5.4
# 3292                    0.28                 0.05             0.0
# ...                      ...                  ...             ...
# 3648                    0.37                 0.18             2.3
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 3288              1.5             0.2  ...                -6.0
# 3289             -1.0            -1.8  ...                -8.1
# 3290             -3.1            -6.2  ...                -5.8
# 3291             -3.7            -6.5  ...               -10.8
# 3292             -4.1            -6.4  ...               -12.6
# ...               ...             ...  ...                 ...
# 3648              1.0            -3.9  ...                -7.7
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 3288                -1.9               4.9            0.92          1.0259
# 3289                -4.6               4.9            0.93          1.0245
# 3290                -2.7               6.0            0.79          1.0236
# 3291                -5.8               1.9            0.86          1.0231
# 3292                -8.3               2.0            0.92          1.0181
# ...                  ...               ...             ...             ...
# 3648                -2.7               4.6            0.84          1.0091
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 3288                    0.22                 0.00              0.6
# 3289                    0.08                 0.00             -0.4
# 3290                    0.69                 0.00             -0.1
# 3291                    0.68                 0.00             -2.4
# 3292                    0.18                 0.16             -4.4
# ...                      ...                  ...              ...
# 3648                    0.58                 0.08              4.6
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
#
#       TOURS_temp_min  TOURS_temp_max
# 3288            -0.5             1.7
# 3289            -1.1             0.4
# 3290            -1.4             1.1
# 3291            -5.3             0.5
# 3292            -6.9            -1.9
# ...              ...             ...
# 3648            -0.5             9.7
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
#
# [365 rows x 165 columns]

# %% [markdown]
# * Maak 4 verschillende DataFrames aan, één voor elk van deze steden: Basel, Oslo, Roma en Maastricht. Geef ze respectievelijk volgende namen: `df_Basel`, `df_Oslo`, `df_Roma` en `df_Maastricht`.
# * Elk dataframe moet de kolom met de datum en de maand bevatten en al de kolommen met de gegevens van de betreffende stad.

# %%
#New dataframes
df_Basel = df_weather.filter(like= "BASEL")
df_Basel["DATE"] = df_weather["DATE"]
df_Basel["MONTH"] = df_weather["MONTH"]
df_Oslo = df_weather.filter(like = "OSLO")
df_Oslo["DATE"] = df_weather["DATE"]
df_Oslo["MONTH"] = df_weather["MONTH"]
df_Roma = df_weather.filter(like = "ROMA")
df_Roma["DATE"] = df_weather["DATE"]
df_Roma["MONTH"] = df_weather["MONTH"]
df_Maastricht = df_weather.filter(like = "MAASTRICHT")
df_Maastricht["DATE"] = df_weather["DATE"]
df_Maastricht["MONTH"] = df_weather["MONTH"]
print(df_Maastricht)
# Out:
#       MAASTRICHT_cloud_cover  MAASTRICHT_wind_speed  MAASTRICHT_wind_gust  \
# 3288                       8                    1.4                   4.0
# 3289                       7                    2.8                   8.0
# 3290                       3                    2.2                   7.0
# 3291                       8                    4.5                   9.0
# 3292                       6                    5.1                  11.0
# ...                      ...                    ...                   ...
# 3648                       7                    8.0                  15.0
# 3649                       7                    4.0                  11.0
# 3650                       6                    3.6                   8.0
# 3651                       8                    4.2                   9.0
# 3652                       8                    3.3                   7.0
#
#       MAASTRICHT_humidity  MAASTRICHT_pressure  MAASTRICHT_global_radiation  \
# 3288                 0.98               1.0299                         0.11
# 3289                 0.94               1.0288                         0.08
# 3290                 0.90               1.0282                         0.61
# 3291                 0.81               1.0208                         0.11
# 3292                 0.95               1.0197                         0.14
# ...                   ...                  ...                          ...
# 3648                 0.85               1.0024                         0.08
# 3649                 0.89               1.0053                         0.10
# 3650                 0.92               0.9976                         0.11
# 3651                 0.94               0.9925                         0.10
# 3652                 0.98               0.9948                         0.03
#
#       MAASTRICHT_precipitation  MAASTRICHT_sunshine  MAASTRICHT_temp_mean  \
# 3288                      0.00                  0.0                  -3.8
# 3289                      0.00                  0.0                  -1.2
# 3290                      0.00                  7.0                  -3.5
# 3291                      0.02                  0.0                  -0.8
# 3292                      0.72                  0.5                  -2.9
# ...                        ...                  ...                   ...
# 3648                      0.09                  0.0                   3.3
# 3649                      0.02                  0.0                   2.6
# 3650                      1.07                  0.0                   1.7
# 3651                      0.63                  0.0                   6.8
# 3652                      0.16                  0.0                   0.0
#
#       MAASTRICHT_temp_min  MAASTRICHT_temp_max       DATE  MONTH
# 3288                 -6.6                 -2.0 2009-01-01      1
# 3289                 -3.8                  0.1 2009-01-02      1
# 3290                 -8.1                  0.3 2009-01-03      1
# 3291                 -1.9                  0.1 2009-01-04      1
# 3292                 -9.3                 -0.9 2009-01-05      1
# ...                   ...                  ...        ...    ...
# 3648                  1.7                  4.8 2009-12-27     12
# 3649                 -0.5                  4.1 2009-12-28     12
# 3650                 -1.0                  8.4 2009-12-29     12
# 3651                  1.2                 10.1 2009-12-30     12
# 3652                 -1.1                  1.3 2009-12-31     12
#
# [365 rows x 13 columns]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Basel["DATE"] = df_weather["DATE"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Basel["MONTH"] = df_weather["MONTH"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Oslo["DATE"] = df_weather["DATE"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Oslo["MONTH"] = df_weather["MONTH"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Roma["DATE"] = df_weather["DATE"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Roma["MONTH"] = df_weather["MONTH"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maastricht["DATE"] = df_weather["DATE"]
# C:\Users\quint\AppData\Local\Temp\ipykernel_24916\3415638777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Maastricht["MONTH"] = df_weather["MONTH"]

# %% [markdown]
# ### Maastricht
# Teken een grafiek met daarop volgende informatie over de temperatuurmetingen in de loop van de tijd in Maastricht:
# * Temperatuur in °C wordt op de y-as getoond
# * Gemiddelde temperatuur in het oranje (orange)
# * Max temperatuur in rood (red)
# * Min temperatuur in blauw (blue)
# * Toon ook een legende met gepaste labels die aanduiden welke data er wordt getoond
# * Zorg voor correcte as-labels en titel
# * Zorg dat er voor elke maand een markering is op de x-as. Label deze met de afkorting voor de maanden (jan, feb, maart etc. )

# %%
#Maastricht

plt.figure(figsize= (10,6))
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_max"], color= "red", label = "max temperatuur")
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_mean"], color= "orange", label="gemiddelde temperatuur")
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_min"], color= "blue", label = "min temperatuur")
plt.xticks(ticks=["2009-01", "2009-02", "2009-03", "2009-04", "2009-05", "2009-06", "2009-07","2009-08", "2009-09","2009-10","2009-11","2009-12"], labels=["JAN", "FEB", "MAR", "APR", "MEI", "JUN", "JUL", "AUG", "SEP", "OKT", "NOV", "DEC"])
plt.legend()
plt.xlabel("date")
plt.ylabel("temp in °C")
# Out:
# Text(0, 0.5, 'temp in °C')

# %% [markdown]
# ### Mean temperatures
# Gemiddelde temperatuur
#
# Maak een nieuwe grafiek met de gemiddelde temperatuur gemeten in de loop van de tijd in de steden waarvoor je aparte dataframes hebt gemaakt. Temperatuur wordt in graden Celcius weergegeven op de y-as.
#
# * Maastricht in oranje (orange)
# * Roma in rood (red)
# * Basel in groen (green)
# * Oslo in blauw (blue)
# * Toon een legende met gepaste labels die duidelijk maken welke gegevens worden getoond
# * Zorg voor correcte as-labels en titel
# * Voorzie markeringen voor elke maand op de x-as, gelabeld met de afkorting van de maanden (jan, feb, maart etc.)
# * Toon een raster (grid)

# %%
#Mean temperatures

# %% [markdown]
# ___

# %% [markdown]
# Controleer je werk grondig en zorg ervoor dat je alle opdrachten hebt gemaakt.
# Er zijn geen testen voorzien voor deze data analyse oefening. Zorg ervoor dat je de juiste namen hebt gebruikt.

# %% [markdown]
# ___
